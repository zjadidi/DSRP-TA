# %% [markdown]
# <a href="https://colab.research.google.com/github/zjadidi/DSRP-TA/blob/main/pop_culture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("pop culture team")
# Out:
# pop culture team
