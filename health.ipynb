# %% [markdown]
# <a href="https://colab.research.google.com/github/zjadidi/DSRP-TA/blob/main/health.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===============================
# Data Manipulation
# ===============================
import pandas as pd
import numpy as np

# ===============================
# Data Visualization
# ===============================
import matplotlib.pyplot as plt

# ===============================
# Statistics
# ===============================
from scipy import stats

# ===============================
# Machine Learning
# ===============================
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (
    accuracy_score,
    mean_squared_error,
    r2_score,
    confusion_matrix,
    ConfusionMatrixDisplay
)

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/frontiertechinstitute/datasets/main/Alzheimer's%20Disease/alzheimers_clean.csv"

alzheimers = pd.read_csv(url)

alzheimers.head()
# Out:
#    Year StateAbbr          State           Class  \
# 0  2015        GU           Guam  Overall Health
# 1  2015        MA  Massachusetts   Mental Health
# 2  2015       MDW        Midwest  Overall Health
# 3  2015        MN      Minnesota   Mental Health
# 4  2015        MO       Missouri  Overall Health
#
#                                        Topic  \
# 0  Recent activity limitations in past month
# 1           Lifetime diagnosis of depression
# 2               Arthritis among older adults
# 3                   Frequent mental distress
# 4               Arthritis among older adults
#
#                                             Question Data_Value_Unit  \
# 0  Mean number of days with activity limitations ...          Number
# 1  Percentage of older adults with a lifetime dia...               %
# 2  Percentage of older adults ever told they have...               %
# 3  Percentage of older adults who are experiencin...               %
# ...
